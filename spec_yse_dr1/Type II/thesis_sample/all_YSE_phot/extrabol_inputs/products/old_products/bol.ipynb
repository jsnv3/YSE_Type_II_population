# %%
import emcee, copy
import numpy as np
from astropy.table import Table,Column
import matplotlib.pyplot as plt
import corner
from astropy.io import ascii
import pandas as pd

# %%
hgw = ascii.read('2020hgw_2p.txt')
hgw_df = hgw.to_pandas()
hgw_df = hgw_df[['Time (MJD)', 'Log10(Bol. Lum)', 'Log10(Bol. Err)']]
hgw_df.rename(columns={'Log10(Bol. Lum)':'Mbol', 'Log10(Bol. Err)':'Mbolerr'}, inplace= True) 
#hgw_df['Mbol'] = -2.5 * hgw_df['Mbol'] + 83.9605452803 + 4.74
#hgw_df['Mbolerr'] = -2.5 * hgw_df['Mbolerr'] + 83.9605452803 + 4.74 
print(hgw_df)
#hgw_df.to_csv('hgw_bol.txt', sep = ' ', header=False, index=False)
# Out:
#     Time (MJD)    Mbol  Mbolerr
# 0          8.0  43.327   42.820
# 1          9.0  43.283   42.704
# 2         10.0  43.247   42.618
# 3         11.0  43.207   42.516
# 4         12.0  43.177   42.435
# ..         ...     ...      ...
# 83        91.0  42.173   41.451
# 84        92.0  42.160   41.443
# 85        93.0  42.147   41.506
# 86        94.0  42.135   41.521
# 87        95.0  42.122   41.545
#
# [88 rows x 3 columns]

# %%
yerr = hgw_df['Mbol'] - hgw_df['Mbolerr'] 
yer_add = hgw_df['Mbol'] + hgw_df['Mbolerr']
print(yerr, yer_add)
# Out:
# 0     0.507
# 1     0.579
# 2     0.629
# 3     0.691
# 4     0.742
#       ...
# 83    0.722
# 84    0.717
# 85    0.641
# 86    0.614
# 87    0.577
# Length: 88, dtype: float64 0     86.147
# 1     85.987
# 2     85.865
# 3     85.723
# 4     85.612
#        ...
# 83    83.624
# 84    83.603
# 85    83.653
# 86    83.656
# 87    83.667
# Length: 88, dtype: float64

# %%
plt.errorbar(hgw_df['Time (MJD)'], hgw_df['Mbol'], yerr = yerr)
plt.xlabel('Days From Explosion')
plt.ylabel('Bolometric Magnitude')
plt.title('SN 2020hgw')
#plt.gca().invert_yaxis()
# Out:
# Text(0.5, 1.0, 'SN 2020hgw')

# %%
jfo = ascii.read('2020jfo_2p.txt')
jfo_df = jfo.to_pandas()
jfo_df = jfo_df[['Time (MJD)', 'Log10(Bol. Lum)', 'Log10(Bol. Err)']]
jfo_df.rename(columns={'Log10(Bol. Lum)':'Mbol', 'Log10(Bol. Err)':'Mbolerr'}, inplace= True) 
jfo_df['Mbol'] = -2.5 * jfo_df['Mbol'] + 83.9605452803 + 4.74
jfo_df['Mbolerr'] = -2.5 * jfo_df['Mbolerr'] + 83.9605452803 + 4.74

# %%
plt.errorbar(jfo_df['Time (MJD)'], jfo_df['Mbol'])
plt.xlabel('Days From Explosion')
plt.ylabel('Bolometric Magnitude')
plt.title('SN 2020jfo')
plt.gca().invert_yaxis()

# %%
jww = ascii.read('2020jww_2p.txt')
jww_df = jww.to_pandas()
jww_df = jww_df[['Time (MJD)', 'Log10(Bol. Lum)', 'Log10(Bol. Err)']]
jww_df.rename(columns={'Log10(Bol. Lum)':'Mbol', 'Log10(Bol. Err)':'Mbolerr'}, inplace= True) 
jww_df['Mbol'] = -2.5 * jww_df['Mbol'] + 83.9605452803 + 4.74
jww_df['Mbolerr'] = -2.5 * jww_df['Mbolerr'] + 83.9605452803 + 4.74

# %%
plt.errorbar(jww_df['Time (MJD)'], jww_df['Mbol'])
plt.xlabel('Days From Explosion')
plt.ylabel('Bolometric Magnitude')
plt.title('SN 2020jww')
plt.gca().invert_yaxis()

# %%
rth = ascii.read('2020rth_2p.txt')
rth_df = rth.to_pandas()
rth_df = rth_df[['Time (MJD)', 'Log10(Bol. Lum)', 'Log10(Bol. Err)']]
rth_df.rename(columns={'Log10(Bol. Lum)':'Mbol', 'Log10(Bol. Err)':'Mbolerr'}, inplace= True) 
rth_df['Mbol'] = -2.5 * rth_df['Mbol'] + 83.9605452803 + 4.74
rth_df['Mbolerr'] = -2.5 * rth_df['Mbolerr'] + 83.9605452803 + 4.74

# %%
plt.errorbar(rth_df['Time (MJD)'], rth_df['Mbol'])
plt.xlabel('Days From Explosion')
plt.ylabel('Bolometric Magnitude')
plt.title('SN 2020rth')
plt.gca().invert_yaxis()

# %%
tly = ascii.read('2020tly_2p.txt')
tly_df = tly.to_pandas()
tly_df = tly_df[['Time (MJD)', 'Log10(Bol. Lum)', 'Log10(Bol. Err)']]
tly_df.to_csv('tly_bol.txt', sep = ' ', header = False, index = False)
tly_df.rename(columns={'Log10(Bol. Lum)':'Mbol', 'Log10(Bol. Err)':'Mbolerr'}, inplace= True) 
tly_df['Mbol'] = -2.5 * tly_df['Mbol'] + 83.9605452803 + 4.74
tly_df['Mbolerr'] = -2.5 * tly_df['Mbolerr'] + 83.9605452803 + 4.74

# %%
plt.errorbar(tly_df['Time (MJD)'], tly_df['Mbol'])
plt.xlabel('Days From Explosion')
plt.ylabel('Bolometric Magnitude')
plt.title('SN 2020tly')
plt.gca().invert_yaxis()

# %%
 
plt.clf()

# Input parameters - superbol file and MJD explosion/discovery date
data_file='jww_bol.txt'
mjd_start=0

def valenti_model(time, theta):
    a, tpt, w, p, m = theta
    return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)

def lnlikelihood(theta, lum, dlum, time):
    model_lum = valenti_model(time, theta)
    
    # Set parameter range value
    a, tpt, w, p, m = theta
    if a<0.01: return(-np.inf)
    if a>10.0: return(-np.inf)
    if tpt<10.0: return(-np.inf)
    if w<0.01: return(-np.inf)
    
    inv_sigma = 1./dlum**2
    return(-0.5 * np.sum((lum-model_lum)**2 * inv_sigma))

def load_table(data_file, mjd_start=mjd_start, mask_date=5):
    # The code will automatically mask data mask_date days from the input reference date.
    # Change this value in order to adjust the amount of data that's included/excluded
    
    table = Table.read(data_file, format='ascii',names=('MJD','lum','dlum'))
    #print(table)
    # Want to fit versus a magnitude rather than actual luminosity, so convert lum to Mbol
    # Here 83.9605452803 = 2.5*log10(3.839e33) for Solar luminosity
    # 4.74 is bolometric luminosity of the Sun
    table['MJD'] = table['MJD']
    Mbol = -2.5*table['lum'] + 83.9605452803 + 4.74
    Mbolerr = -2.5 * table['dlum'] + 83.96 + 4.74 

    
    table.add_column(Column(Mbol, name='Mbol'))
    table.add_column(Column(Mbolerr, name='Mbolerr'))
    
    newcol=Column(table['MJD'].data-mjd_start,name='t_exp')
    table.add_column(newcol)
    
    mask = table['t_exp']>mask_date
    table=table[mask]
   # print(table)
    return(table)

def mcmc_valenti(data_file, ndim=5, nwalkers=100, inflate_errors=0.1):
    
    # I'm adding a parameter to inflate the error bars because the code appears to underfit the
    # late time decline due to nickel, which is primarily what we're interested in
    
    params = [1.7391707763335567, 111.06179709805089, 7.203197652533321, 0.008194307783125725, -13.583601384015793]
    pos = [params + 1e-2*np.random.randn(ndim) for i in range(nwalkers)]
    
    table = load_table(data_file)
    mask = np.abs(table['MJD'] - 58923) < 1
    table = table[~mask]
    table['Mbolerr'] = np.sqrt(table['Mbolerr']**2+inflate_errors**2)
    
    sampler = emcee.EnsembleSampler(nwalkers, ndim, lnlikelihood, 
                                    args=(table['Mbol'],
                                          table['Mbolerr'],
                                          table['t_exp']))
    
    sampler.run_mcmc(pos, 5000, progress=True)
    samples = sampler.chain[:, 99:, :].reshape((-1, ndim))
    
    return(samples)

def get_param_uncertainties(samples):
    
    vals = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                                 zip(*np.percentile(samples, [16, 50, 84],
                                                    axis=0)))
    
    vals = [v for v in vals]
    
    return(vals)
    
samples=mcmc_valenti(data_file)
params=get_param_uncertainties(samples)
   

print('Best-fit parameters:')
for p in copy.copy(params):
    print('Param: {0} + {1} - {2}'.format(p[0], p[1], p[2]))

best_fit=[p[0] for p in copy.copy(params)]
print(best_fit)
table = load_table(data_file)
plt.errorbar(table['MJD']-mjd_start, table['Mbol'], yerr=np.abs(table['Mbol'] - table['Mbolerr']), marker='*', zorder=5)
# print(table['MJD'] - mjd_start)
# print(table['Mbol'])
    
model_lum=valenti_model(table['MJD']-mjd_start, best_fit)

plt.plot(table['MJD']-mjd_start, model_lum, zorder=10)

plt.ylim([-14,-20])
plt.ylabel('Bolometric Magnitude')
plt.xlabel('Time from Explosion')

plt.show()
# Out:
# You must install the tqdm library to use progress indicators with emcee
# C:\Users\jvasq\AppData\Local\Temp\ipykernel_13208\3729947870.py:9: RuntimeWarning: overflow encountered in exp
#   return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)
# Best-fit parameters:
# Param: 5.026427598844327 + 3.509089388647176 - 3.5471758389924233
# Param: 1.5999220336731208e+36 + 1.779481907911072e+58 - 1.5999220336731208e+36
# Param: 4.789919608701685e+34 + 4.217687343634836e+56 - 4.789919608701685e+34
# Param: 0.014553605537246363 + 0.04951988919874536 - 0.04922910744793426
# Param: -13.010869327116259 + 4.668376002156586 - 4.541633273782521
# [5.026427598844327, 1.5999220336731208e+36, 4.789919608701685e+34, 0.014553605537246363, -13.010869327116259]

# %%
plt.clf()

# Input parameters - superbol file and MJD explosion/discovery date
data_file='hgw_bol.txt'
mjd_start=0

def valenti_model(time, theta):
    a, tpt, w, p, m = theta
    return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)

def lnlikelihood(theta, lum, dlum, time):
    model_lum = valenti_model(time, theta)
    
    # Set parameter range value
    a, tpt, w, p, m = theta
    if a<0.01: return(-np.inf)
    if a>10.0: return(-np.inf)
    if tpt<10.0: return(-np.inf)
    if w<0.01: return(-np.inf)
    
    inv_sigma = 1./dlum**2
    return(-0.5 * np.sum((lum-model_lum)**2 * inv_sigma))

def load_table(data_file, mjd_start=mjd_start, mask_date=15):
    # The code will automatically mask data mask_date days from the input reference date.
    # Change this value in order to adjust the amount of data that's included/excluded
    
    table = Table.read(data_file, format='ascii',names=('MJD','lum','dlum'))
    #print(table)
    # Want to fit versus a magnitude rather than actual luminosity, so convert lum to Mbol
    # Here 83.9605452803 = 2.5*log10(3.839e33) for Solar luminosity
    # 4.74 is bolometric luminosity of the Sun
    table['MJD'] = table['MJD']
    Mbol = -2.5*table['lum'] + 83.9605452803 + 4.74
    Mbolerr = -2.5 * table['dlum'] + 83.96 + 4.74 

    
    table.add_column(Column(Mbol, name='Mbol'))
    table.add_column(Column(Mbolerr, name='Mbolerr'))
    
    newcol=Column(table['MJD'].data-mjd_start,name='t_exp')
    table.add_column(newcol)
    
    mask = table['t_exp']>mask_date
    table=table[mask]
   # print(table)
    return(table)

def mcmc_valenti(data_file, ndim=5, nwalkers=100, inflate_errors=0.1):
    
    # I'm adding a parameter to inflate the error bars because the code appears to underfit the
    # late time decline due to nickel, which is primarily what we're interested in
    
    params = [1.7391707763335567, 111.06179709805089, 7.203197652533321, 0.008194307783125725, -13.583601384015793]
    pos = [params + 1e-2*np.random.randn(ndim) for i in range(nwalkers)]
    
    table = load_table(data_file)
    mask = np.abs(table['MJD'] - 58923) < 1
    table = table[~mask]
    table['Mbolerr'] = np.sqrt(table['Mbolerr']**2+inflate_errors**2)
    
    sampler = emcee.EnsembleSampler(nwalkers, ndim, lnlikelihood, 
                                    args=(table['Mbol'],
                                          table['Mbolerr'],
                                          table['t_exp']))
    
    sampler.run_mcmc(pos, 5000, progress=True)
    samples = sampler.chain[:, 99:, :].reshape((-1, ndim))
    
    return(samples)

def get_param_uncertainties(samples):
    
    vals = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                                 zip(*np.percentile(samples, [16, 50, 84],
                                                    axis=0)))
    
    vals = [v for v in vals]
    
    return(vals)
    
samples=mcmc_valenti(data_file)
params=get_param_uncertainties(samples)
   

print('Best-fit parameters:')
for p in copy.copy(params):
    print('Param: {0} + {1} - {2}'.format(p[0], p[1], p[2]))

best_fit=[p[0] for p in copy.copy(params)]
print(best_fit)
table = load_table(data_file)
plt.errorbar(table['MJD']-mjd_start, table['Mbol'], yerr=np.abs(table['Mbol'] - table['Mbolerr']), marker='*', zorder=5)
# print(table['MJD'] - mjd_start)
# print(table['Mbol'])
    
model_lum=valenti_model(table['MJD']-mjd_start, best_fit)

plt.plot(table['MJD']-mjd_start, model_lum, zorder=10)

plt.ylim([-12,-20])
plt.ylabel('Bolometric Magnitude')
plt.xlabel('Time from Explosion')

plt.show()
# Out:
# You must install the tqdm library to use progress indicators with emcee
# C:\Users\jvasq\AppData\Local\Temp\ipykernel_16876\1691503661.py:9: RuntimeWarning: overflow encountered in exp
#   return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)
# Best-fit parameters:
# Param: 4.9814993162153485 + 3.553650428644339 - 3.5117446187846757
# Param: 1.4375804648071842e+33 + 2.145702853842441e+54 - 1.4375804648071842e+33
# Param: 3.52543043142667e+35 + 1.839591053575909e+56 - 3.52543043142667e+35
# Param: 0.02432410590520752 + 0.08213674439591574 - 0.0818816266969407
# Param: -16.116106009892402 + 5.467492588071929 - 5.37418840107053
# [4.9814993162153485, 1.4375804648071842e+33, 3.52543043142667e+35, 0.02432410590520752, -16.116106009892402]

# %%
plt.clf()

# Input parameters - superbol file and MJD explosion/discovery date
data_file='jfo_bol.txt'
mjd_start=0

def valenti_model(time, theta):
    a, tpt, w, p, m = theta
    return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)

def lnlikelihood(theta, lum, dlum, time):
    model_lum = valenti_model(time, theta)
    
    # Set parameter range value
    a, tpt, w, p, m = theta
    if a<0.01: return(-np.inf)
    if a>10.0: return(-np.inf)
    if tpt<10.0: return(-np.inf)
    if w<0.01: return(-np.inf)
    
    inv_sigma = 1./dlum**2
    return(-0.5 * np.sum((lum-model_lum)**2 * inv_sigma))

def load_table(data_file, mjd_start=mjd_start, mask_date=15):
    # The code will automatically mask data mask_date days from the input reference date.
    # Change this value in order to adjust the amount of data that's included/excluded
    
    table = Table.read(data_file, format='ascii',names=('MJD','lum','dlum'))
    #print(table)
    # Want to fit versus a magnitude rather than actual luminosity, so convert lum to Mbol
    # Here 83.9605452803 = 2.5*log10(3.839e33) for Solar luminosity
    # 4.74 is bolometric luminosity of the Sun
    table['MJD'] = table['MJD']
    Mbol = -2.5*table['lum'] + 83.9605452803 + 4.74
    Mbolerr = -2.5 * table['dlum'] + 83.96 + 4.74 

    
    table.add_column(Column(Mbol, name='Mbol'))
    table.add_column(Column(Mbolerr, name='Mbolerr'))
    
    newcol=Column(table['MJD'].data-mjd_start,name='t_exp')
    table.add_column(newcol)
    
    mask = table['t_exp']>mask_date
    table=table[mask]
   # print(table)
    return(table)

def mcmc_valenti(data_file, ndim=5, nwalkers=100, inflate_errors=0.1):
    
    # I'm adding a parameter to inflate the error bars because the code appears to underfit the
    # late time decline due to nickel, which is primarily what we're interested in
    
    params = [1.7391707763335567, 111.06179709805089, 7.203197652533321, 0.008194307783125725, -13.583601384015793]
    pos = [params + 1e-2*np.random.randn(ndim) for i in range(nwalkers)]
    
    table = load_table(data_file)
    mask = np.abs(table['MJD'] - 58923) < 1
    table = table[~mask]
    table['Mbolerr'] = np.sqrt(table['Mbolerr']**2+inflate_errors**2)
    
    sampler = emcee.EnsembleSampler(nwalkers, ndim, lnlikelihood, 
                                    args=(table['Mbol'],
                                          table['Mbolerr'],
                                          table['t_exp']))
    
    sampler.run_mcmc(pos, 5000, progress=True)
    samples = sampler.chain[:, 99:, :].reshape((-1, ndim))
    
    return(samples)

def get_param_uncertainties(samples):
    
    vals = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                                 zip(*np.percentile(samples, [16, 50, 84],
                                                    axis=0)))
    
    vals = [v for v in vals]
    
    return(vals)
    
samples=mcmc_valenti(data_file)
params=get_param_uncertainties(samples)
   

print('Best-fit parameters:')
for p in copy.copy(params):
    print('Param: {0} + {1} - {2}'.format(p[0], p[1], p[2]))

best_fit=[p[0] for p in copy.copy(params)]
print(best_fit)
table = load_table(data_file)
plt.errorbar(table['MJD']-mjd_start, table['Mbol'], yerr=np.abs(table['Mbol'] - table['Mbolerr']), marker='*', zorder=5)
# print(table['MJD'] - mjd_start)
# print(table['Mbol'])
    
model_lum=valenti_model(table['MJD']-mjd_start, best_fit)

plt.plot(table['MJD']-mjd_start, model_lum, zorder=10)

plt.ylim([-12,-20])
plt.ylabel('Bolometric Magnitude')
plt.xlabel('Time from Explosion')

plt.show()
# Out:
# You must install the tqdm library to use progress indicators with emcee
# C:\Users\jvasq\AppData\Local\Temp\ipykernel_13208\1514062207.py:9: RuntimeWarning: overflow encountered in exp
#   return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)
# Best-fit parameters:
# Param: 4.9848496636169335 + 3.5457647392246754 - 3.5577389471398524
# Param: 2.2224499470744278e+30 + 1.2063565063597908e+54 - 2.2224499470744278e+30
# Param: 5.945398254585304e+32 + 1.5832067929712442e+56 - 5.945398254585304e+32
# Param: 0.021313862095874242 + 0.17235030571334647 - 0.1736615412625415
# Param: -15.094865823709782 + 7.230586275617462 - 7.101760847546487
# [4.9848496636169335, 2.2224499470744278e+30, 5.945398254585304e+32, 0.021313862095874242, -15.094865823709782]

# %%
plt.clf()

# Input parameters - superbol file and MJD explosion/discovery date
data_file='rth_bol.txt'
mjd_start=0

def valenti_model(time, theta):
    a, tpt, w, p, m = theta
    return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)

def lnlikelihood(theta, lum, dlum, time):
    model_lum = valenti_model(time, theta)
    
    # Set parameter range value
    a, tpt, w, p, m = theta
    if a<0.01: return(-np.inf)
    if a>10.0: return(-np.inf)
    if tpt<10.0: return(-np.inf)
    if w<0.01: return(-np.inf)
    
    inv_sigma = 1./dlum**2
    return(-0.5 * np.sum((lum-model_lum)**2 * inv_sigma))

def load_table(data_file, mjd_start=mjd_start, mask_date=15):
    # The code will automatically mask data mask_date days from the input reference date.
    # Change this value in order to adjust the amount of data that's included/excluded
    
    table = Table.read(data_file, format='ascii',names=('MJD','lum','dlum'))
    #print(table)
    # Want to fit versus a magnitude rather than actual luminosity, so convert lum to Mbol
    # Here 83.9605452803 = 2.5*log10(3.839e33) for Solar luminosity
    # 4.74 is bolometric luminosity of the Sun
    table['MJD'] = table['MJD']
    Mbol = -2.5*table['lum'] + 83.9605452803 + 4.74
    Mbolerr = -2.5 * table['dlum'] + 83.96 + 4.74 

    
    table.add_column(Column(Mbol, name='Mbol'))
    table.add_column(Column(Mbolerr, name='Mbolerr'))
    
    newcol=Column(table['MJD'].data-mjd_start,name='t_exp')
    table.add_column(newcol)
    
    mask = table['t_exp']>mask_date
    table=table[mask]
   # print(table)
    return(table)

def mcmc_valenti(data_file, ndim=5, nwalkers=100, inflate_errors=0.1):
    
    # I'm adding a parameter to inflate the error bars because the code appears to underfit the
    # late time decline due to nickel, which is primarily what we're interested in
    
    params = [1.7391707763335567, 111.06179709805089, 7.203197652533321, 0.008194307783125725, -13.583601384015793]
    pos = [params + 1e-2*np.random.randn(ndim) for i in range(nwalkers)]
    
    table = load_table(data_file)
    mask = np.abs(table['MJD'] - 58923) < 1
    table = table[~mask]
    table['Mbolerr'] = np.sqrt(table['Mbolerr']**2+inflate_errors**2)
    
    sampler = emcee.EnsembleSampler(nwalkers, ndim, lnlikelihood, 
                                    args=(table['Mbol'],
                                          table['Mbolerr'],
                                          table['t_exp']))
    
    sampler.run_mcmc(pos, 5000, progress=True)
    samples = sampler.chain[:, 99:, :].reshape((-1, ndim))
    
    return(samples)

def get_param_uncertainties(samples):
    
    vals = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                                 zip(*np.percentile(samples, [16, 50, 84],
                                                    axis=0)))
    
    vals = [v for v in vals]
    
    return(vals)
    
samples=mcmc_valenti(data_file)
params=get_param_uncertainties(samples)
   

print('Best-fit parameters:')
for p in copy.copy(params):
    print('Param: {0} + {1} - {2}'.format(p[0], p[1], p[2]))

best_fit=[p[0] for p in copy.copy(params)]
print(best_fit)
table = load_table(data_file)
plt.errorbar(table['MJD']-mjd_start, table['Mbol'], yerr=np.abs(table['Mbol'] - table['Mbolerr']), marker='*', zorder=5)
# print(table['MJD'] - mjd_start)
# print(table['Mbol'])
    
model_lum=valenti_model(table['MJD']-mjd_start, best_fit)

plt.plot(table['MJD']-mjd_start, model_lum, zorder=10)

plt.ylim([-12,-20])
plt.ylabel('Bolometric Magnitude')
plt.xlabel('Time from Explosion')

plt.show()
# Out:
# You must install the tqdm library to use progress indicators with emcee
# C:\Users\jvasq\AppData\Local\Temp\ipykernel_13208\2900229448.py:9: RuntimeWarning: overflow encountered in exp
#   return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)
# Best-fit parameters:
# Param: 4.966125105963467 + 3.5871120047086382 - 3.522563983324198
# Param: 3.6335658070283634e+35 + 2.720075705021146e+56 - 3.6335658070283634e+35
# Param: 2.268900905314083e+32 + 4.814858140779243e+54 - 2.268900905314083e+32
# Param: 0.010834359206731595 + 0.05755170124013681 - 0.05762738393458809
# Param: -12.422088960741398 + 4.983504022165802 - 5.01873900861629
# [4.966125105963467, 3.6335658070283634e+35, 2.268900905314083e+32, 0.010834359206731595, -12.422088960741398]

# %%
plt.clf()

# Input parameters - superbol file and MJD explosion/discovery date
data_file='tly_bol.txt'
mjd_start=0

def valenti_model(time, theta):
    a, tpt, w, p, m = theta
    return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)

def lnlikelihood(theta, lum, dlum, time):
    model_lum = valenti_model(time, theta)
    
    # Set parameter range value
    a, tpt, w, p, m = theta
    if a<0.01: return(-np.inf)
    if a>10.0: return(-np.inf)
    if tpt<10.0: return(-np.inf)
    if w<0.01: return(-np.inf)
    
    inv_sigma = 1./dlum**2
    return(-0.5 * np.sum((lum-model_lum)**2 * inv_sigma))

def load_table(data_file, mjd_start=mjd_start, mask_date=15):
    # The code will automatically mask data mask_date days from the input reference date.
    # Change this value in order to adjust the amount of data that's included/excluded
    
    table = Table.read(data_file, format='ascii',names=('MJD','lum','dlum'))
    #print(table)
    # Want to fit versus a magnitude rather than actual luminosity, so convert lum to Mbol
    # Here 83.9605452803 = 2.5*log10(3.839e33) for Solar luminosity
    # 4.74 is bolometric luminosity of the Sun
    table['MJD'] = table['MJD']
    Mbol = -2.5*table['lum'] + 83.9605452803 + 4.74
    Mbolerr = -2.5 * table['dlum'] + 83.96 + 4.74 

    
    table.add_column(Column(Mbol, name='Mbol'))
    table.add_column(Column(Mbolerr, name='Mbolerr'))
    
    newcol=Column(table['MJD'].data-mjd_start,name='t_exp')
    table.add_column(newcol)
    
    mask = table['t_exp']>mask_date
    table=table[mask]
   # print(table)
    return(table)

def mcmc_valenti(data_file, ndim=5, nwalkers=100, inflate_errors=0.1):
    
    # I'm adding a parameter to inflate the error bars because the code appears to underfit the
    # late time decline due to nickel, which is primarily what we're interested in
    
    params = [1.7391707763335567, 111.06179709805089, 7.203197652533321, 0.008194307783125725, -13.583601384015793]
    pos = [params + 1e-2*np.random.randn(ndim) for i in range(nwalkers)]
    
    table = load_table(data_file)
    mask = np.abs(table['MJD'] - 58923) < 1
    table = table[~mask]
    table['Mbolerr'] = np.sqrt(table['Mbolerr']**2+inflate_errors**2)
    
    sampler = emcee.EnsembleSampler(nwalkers, ndim, lnlikelihood, 
                                    args=(table['Mbol'],
                                          table['Mbolerr'],
                                          table['t_exp']))
    
    sampler.run_mcmc(pos, 5000, progress=True)
    samples = sampler.chain[:, 99:, :].reshape((-1, ndim))
    
    return(samples)

def get_param_uncertainties(samples):
    
    vals = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                                 zip(*np.percentile(samples, [16, 50, 84],
                                                    axis=0)))
    
    vals = [v for v in vals]
    
    return(vals)
    
samples=mcmc_valenti(data_file)
params=get_param_uncertainties(samples)
   

print('Best-fit parameters:')
for p in copy.copy(params):
    print('Param: {0} + {1} - {2}'.format(p[0], p[1], p[2]))

best_fit=[p[0] for p in copy.copy(params)]
print(best_fit)
table = load_table(data_file)
plt.errorbar(table['MJD']-mjd_start, table['Mbol'], yerr=np.abs(table['Mbol'] - table['Mbolerr']), marker='*', zorder=5)
# print(table['MJD'] - mjd_start)
# print(table['Mbol'])
    
model_lum=valenti_model(table['MJD']-mjd_start, best_fit)

plt.plot(table['MJD']-mjd_start, model_lum, zorder=10)

plt.ylim([-12,-20])
plt.ylabel('Bolometric Magnitude')
plt.xlabel('Time from Explosion')

plt.show()
# Out:
# You must install the tqdm library to use progress indicators with emcee
# C:\Users\jvasq\AppData\Local\Temp\ipykernel_13208\1431688776.py:9: RuntimeWarning: overflow encountered in exp
#   return(-a/(1. + np.exp((time-tpt)/w))+p*time+m)
# Best-fit parameters:
# Param: 5.073884811375532 + 3.509067708302368 - 3.558975082122157
# Param: 1.4632791242055432e+31 + 1.1887668285451282e+52 - 1.4632791242055432e+31
# Param: 4.4232697473573716e+29 + 1.0889140326709329e+49 - 4.4232697473573716e+29
# Param: 0.014336968420299839 + 0.13967057071417277 - 0.14145553034758745
# Param: -13.427915818160457 + 7.103743581446893 - 7.100361445126822
# [5.073884811375532, 1.4632791242055432e+31, 4.4232697473573716e+29, 0.014336968420299839, -13.427915818160457]
