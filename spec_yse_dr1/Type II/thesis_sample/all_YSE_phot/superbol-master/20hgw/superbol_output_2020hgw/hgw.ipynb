# %% [markdown]
# # COMBINED ZTF/PANSTARRS g AND r BANDS, REMOVED ATLAS

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from astropy.table import Table

# %%
table = Table.read('logL-obs_2020hgw_SDAUBgVriz.txt', format = 'ascii', names = ('MJD', 'lum', 'dlum'))

# %%
plt.errorbar(table['MJD'], table['lum'], yerr = table['dlum'], marker = '*')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## superbol settings
# 1. id SN + files + filters
#
#     -SDAUBgVriz
#
#     -no range limit
# 2. ref band
#
#     -use all bands
#
#     -r as ref (most points)
#
#     -auto max
#
#     -no shift to max
#
#     -DM = 0.043
#
#     -no time dilation correction
# 3. flux scale
#
#     -not abs mag
# 4. interp to ref epochs
#
#     -auto interp w/ constant color
# 5. extinction/k-correction
#     -E(B-V) = 0.011
#
#     -default phot systems
#
#     -convert to rest-frame
# 6. bbfit, integrate
#
#     -no absorption applied
#
#     -10000 K
#
#     -1.0e15cm

# %%
interp_lc = table.read('interpolated-lcs_2020hgw_SDAUBgVriz.txt', format = 'ascii')

# %%
interp_lc
# Out:
# <Table length=62>
#  #phase     S      err      D     err_1  ...    i     err_8     z     err_9
# float64  float64 float64 float64 float64 ... float64 float64 float64 float64
# -------- ------- ------- ------- ------- ... ------- ------- ------- -------
# 58942.48   20.72    0.16   20.71    0.16 ...   21.66    0.26    21.6    0.38
# 58954.44   17.72     0.1   17.71     0.1 ...   18.66    0.25    18.6    0.36
# 58954.44   17.71     0.1   17.71     0.1 ...   18.66    0.25    18.6    0.36
# 58955.43   17.56     0.1   17.56     0.1 ...   18.51    0.25   18.45    0.36
# 58956.34   17.48     0.1   17.48     0.1 ...   18.43    0.25   18.37    0.36
# 58956.47    18.0     0.1    18.0    0.09 ...   18.95    0.25   18.89    0.36
# 58960.46   17.15    0.08   17.15    0.08 ...   18.09    0.25   18.03    0.36
# 58961.41   17.16    0.07   17.16    0.07 ...   18.09    0.25   18.05    0.36
# 58964.28   17.25    0.06   17.24    0.06 ...   18.08    0.25   18.13    0.36
# 58967.34   17.28    0.05   17.27    0.05 ...   18.07    0.25   18.16    0.35
#      ...     ...     ...     ...     ... ...     ...     ...     ...     ...
# 59598.62   19.81     1.2   19.89     1.2 ...   21.32    0.25   21.26    0.35
# 59600.62   20.55     1.2   20.63     1.2 ...   21.35    0.25   21.24    0.35
# 59623.56   20.22     1.2    20.3     1.2 ...   21.57    0.25   21.21    0.35
# 59693.39   19.63     1.2   19.71     1.2 ...   22.09    0.25   21.09    0.35
# 59717.35   20.46     1.2   20.55     1.2 ...   22.26    0.25   21.05    0.35
# 59726.27   20.12     1.2    20.2     1.2 ...   21.62    0.25   21.03    0.35
# 59731.26   20.07     1.2   20.16     1.2 ...   21.38    0.25   21.02    0.35
# 59734.27   20.22     1.2   20.31     1.2 ...   21.24    0.25   21.02    0.35
# 59767.27   19.94     1.2   20.02     1.2 ...   20.96    0.41   20.96    0.35
#  59776.3    20.3     1.2   20.38     1.2 ...   21.32    0.49   21.32    0.36

# %%
times = interp_lc['#phase']

# %%
plt.figure(figsize = (10,11))
plt.errorbar(times, interp_lc['S'], interp_lc['err'], marker = 'o', label = 'UVW2', color = 'purple')
plt.errorbar(times, interp_lc['D'], interp_lc['err_1'], label = 'UVM2', marker = 'o', color = 'pink')
plt.errorbar(times, interp_lc['A'], interp_lc['err_2'], label = 'UVM1', marker = 'o')
plt.errorbar(times, interp_lc['U'], interp_lc['err_3'], label = 'U', marker = 'o', color = 'violet')
plt.errorbar(times, interp_lc['B'], interp_lc['err_4'], label = 'B', marker = 'o', color = 'blue')
plt.errorbar(times, interp_lc['g'], interp_lc['err_5'], label = 'g', marker = 'o', color = 'green')
plt.errorbar(times, interp_lc['V'], interp_lc['err_6'], label = 'V', marker = 'o')
plt.errorbar(times, interp_lc['r'], interp_lc['err_7'], label = 'r', marker = 'o', color = 'red')
plt.errorbar(times, interp_lc['i'], interp_lc['err_8'], label = 'i', marker = 'o', color = 'gold')
plt.errorbar(times, interp_lc['z'], interp_lc['err_9'], label = 'z', marker = 'o', color = 'k')
plt.gca().invert_yaxis()
plt.legend(ncol = 5)
plt.xlabel('MJD')
plt.ylabel('App Mag')
plt.title('2020hgw, ref = r')
# Out:
# Text(0.5, 1.0, '2020hgw, ref = r')
