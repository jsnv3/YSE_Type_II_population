# %%
import numpy as np 
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
table = Table.read('logL-obs_2020tly_gcwroiz.txt', format = 'ascii', names = ('MJD', 'lum', 'dlum'))

# %%
plt.errorbar(table['MJD'], table['lum'], yerr=table['dlum'])
plt.title('2020tly Bol. Lum.')
plt.xlabel('MJD')
plt.ylabel('Luminosity')
# Out:
# Text(0, 0.5, 'Luminosity')

# %% [markdown]
# ## superbol settings
# 1. id SN + files + filters
#
#     -cgiorwz
#
#     -no range limit
# 2. ref band
#
#     -use all bands
#
#     -g as ref
#
#     -auto max
#
#     -no shift to max
#
#     -DM = 0.058
#
#     -no time dilation correction
# 3. flux scale
#
#     -not abs mag
# 4. interp to ref epochs
#
#     -auto interp w/ constant color
# 5. extinction/k-correction
#     -E(B-V) = 0.071
#
#     -default phot systems
#
#     -convert to rest-frame
# 6. bbfit, integrate
#
#     -no absorption applied
#
#     -10000 K
#
#     -1.0e15cm

# %%
interp_lc = table.read('interpolated-lcs_2020tly_gcwroiz.txt', format = 'ascii')

# %%
interp_lc
# Out:
# <Table length=39>
#  #phase     g      err      c     err_1  ...    i     err_5     z     err_6
# float64  float64 float64 float64 float64 ... float64 float64 float64 float64
# -------- ------- ------- ------- ------- ... ------- ------- ------- -------
#  59060.5   22.27    0.28   22.66    0.48 ...   23.32    0.27    22.2    0.48
# 59108.39   20.14    0.27   20.53    0.41 ...   21.19    0.14   20.07    0.38
# 59108.39   20.14    0.27   20.53    0.41 ...   21.19    0.14   20.07    0.38
# 59109.41   19.27    0.27   20.06    0.41 ...   21.01    0.14   19.55    0.38
# 59110.36   19.08    0.27   19.62    0.41 ...   20.85    0.14   19.29    0.38
#  59111.5   19.01    0.27   18.83    0.41 ...   20.64    0.14   19.19    0.38
#  59113.3   19.01    0.27   18.99    0.41 ...   20.33    0.14   19.06    0.38
# 59113.34   19.01    0.27   18.99    0.41 ...   20.32    0.14   19.18    0.38
# 59115.31   19.08    0.27   19.16    0.41 ...   19.97    0.14   19.04    0.38
# 59116.34   19.14    0.27   18.83    0.41 ...   19.79    0.14   19.07    0.38
#      ...     ...     ...     ...     ... ...     ...     ...     ...     ...
# 59158.39   20.87    0.27   19.57    0.41 ...   19.52    0.14   19.76    0.38
# 59167.23   20.95    0.27   20.26    0.41 ...   19.62    0.14   19.85    0.38
# 59169.19   20.88    0.27   20.33    0.41 ...   19.64    0.14   19.87    0.38
# 59173.22   21.22    0.27   20.48    0.41 ...   19.76    0.14   19.91    0.38
# 59173.38   21.23    0.27   20.49    0.41 ...   19.76    0.14   19.91    0.38
# 59182.36   21.71    0.27   20.83    0.41 ...   20.02    0.14    20.0    0.38
# 59186.35   21.92    0.27   20.98    0.41 ...   20.14    0.14   20.14    0.38
#  59390.6   22.52    0.27   22.39     1.2 ...   21.55     1.2   21.72    0.38
# 59400.57   23.14    0.27   24.04     1.2 ...    23.2     1.2    21.8    0.38
# 59757.59   22.87     1.2   23.76     1.2 ...   22.93     1.2   21.53    0.42

# %%
times = interp_lc['#phase']
plt.figure(figsize=(10,11))
plt.errorbar(times, interp_lc['g'], interp_lc['err'], label = 'g', marker = 'o', color = 'green')
plt.errorbar(times, interp_lc['c'], interp_lc['err_1'], label = 'c-ATLAS', marker = 'o', color = 'cyan')
plt.errorbar(times, interp_lc['w'], interp_lc['err_2'], label = 'w', marker = 'o', color = 'gray')
plt.errorbar(times, interp_lc['r'], interp_lc['err_3'], label = 'r', marker = 'o', color = 'r')
plt.errorbar(times, interp_lc['o'], interp_lc['err_4'], label = 'o-ATLAS', marker = 'o', color = 'orange')
plt.errorbar(times, interp_lc['i'], interp_lc['err_5'], label = 'i', marker = 'o', color = 'gold')
plt.errorbar(times, interp_lc['z'], interp_lc['err_6'], label = 'z', marker = 'o', color = 'k')
plt.gca().invert_yaxis()
plt.xlabel('MJD')
plt.ylabel('App Mag')
plt.legend(ncol = 3)
plt.title('2020tly, ref = g')
# Out:
# Text(0.5, 1.0, '2020tly, ref = g')
