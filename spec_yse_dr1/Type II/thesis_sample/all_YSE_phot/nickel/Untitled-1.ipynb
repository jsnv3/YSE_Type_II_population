# %%
import pandas as pd 
import numpy as np

# %%
hgw = pd.read_csv('2020hgw_FPztf_2p.txt', sep = ' ') 
jfo = pd.read_csv('2020jfo_2p.txt', sep = ' ')
jww = pd.read_csv('2020jww_FPztf_2p.txt', sep = ' ')
rth = pd.read_csv('2020rth_FPztf_2p.txt', sep = ' ')

# %%
hgw
# Out:
#      Time (MJD)  Temp./1e3 (K)  Temp. Err.  Radius/1e15 (cm)  Radius Err.  \
# 0        -4.128         19.956       1.880             0.528        0.045
# 1        -3.120         19.103       1.679             0.581        0.048
# 2        -2.113         25.094       2.115             0.418        0.029
# 3        -1.105         26.722       2.337             0.430        0.030
# 4        -0.097         22.137       1.157             0.547        0.024
# ..          ...            ...         ...               ...          ...
# 137     133.928          2.500       0.000             3.068        0.084
# 138     134.936          2.500       0.000             3.028        0.084
# 139     135.944          2.500       0.000             2.988        0.084
# 140     136.951          2.500       0.000             2.949        0.084
# 141     137.959          2.500       0.000             2.910        0.084
#
#                                              Bol. Lum  \
# ...

# %%
for i in hgw.columns:
    print(i)
# Out:
# Time (MJD)
# Temp./1e3 (K)
# Temp. Err.
# Radius/1e15 (cm)
# Radius Err.
# Bol. Lum
# Bol. Err

# %%
hgw = hgw.drop(columns = ['Temp./1e3 (K)', 'Temp. Err.', 'Radius/1e15 (cm)', 'Radius Err.'])
hgw.to_csv('hgw_bol_LC', sep = ' ', index= False)

# %%
jfo = jfo.drop(columns = ['Temp./1e3 (K)', 'Temp. Err.', 'Radius/1e15 (cm)', 'Radius Err.'])
jfo.to_csv('jfo_bol_LC', sep = ' ', index= False)

# %%
jww = jww.drop(columns = ['Temp./1e3 (K)', 'Temp. Err.', 'Radius/1e15 (cm)', 'Radius Err.'])
jww.to_csv('jww_bol_LC', sep = ' ', index= False)

# %%
rth = rth.drop(columns = ['Temp./1e3 (K)', 'Temp. Err.', 'Radius/1e15 (cm)', 'Radius Err.'])
rth.to_csv('rth_bol_LC', sep = ' ', index= False)

# %%
jfo
# Out:
#      Time (MJD)                                   Log10(Bol. Lum)  \
# 0        -5.519  20255670093059272401651865671131846653509632.000
# 1        -4.517  30333429099449356119887870542440411089076224.000
# 2        -3.514  30063259063292249926634744409534783121522688.000
# 3        -2.512   3887092243045100054663853354682770933153792.000
# 4        -1.509   3623752948758180357882774591367676466036736.000
# ..          ...                                               ...
# 387     382.432      3090026831791828972321100934216096415744.000
# 388     383.435      3063799294012746638408235884340639170560.000
# 389     384.437      3037648149833497314393225275111643283456.000
# 390     385.440      3562021651342839317317381669321170747392.000
# 391     386.442      3498581396233116335532333623648018497536.000
#
#                                       Log10(Bol. Err)
# 0    16842306173459916733903199513529301235400704.000
# 1     5159721969969094909063302631251781659656192.000
# ...

# %%
jfo.dtypes
# Out:
# Time (MJD)         float64
# Log10(Bol. Lum)     object
# Log10(Bol. Err)     object
# dtype: object
