# %%
import os 
parent = 'C:/Users/JV/RSG_project/spec_yse_dr1/Type II'
files = []
for filename in os.listdir(parent):
    if filename.endswith('.dat'):
        with open(filename) as f:
            for i, line in enumerate(f):
                if 'SPEC_CLASS_BROAD' in line:
                    classification = line.split()
                    if classification[2] != 'II':
                        print(filename, 'imposter')
                    else:
                        files.append(filename)
print(len(files))
# Out:
# 114

# %%
II_P = []
II_n = []
II_b = [] 
II = []
for filename in os.listdir(parent):
    if filename.endswith('.dat'):
        with open(filename) as f:
            data =f.readlines()
            print(filename,data[19])
            subtype = data[19].split()
            if subtype[2] == 'IIP':
                II_P.append(filename)
            elif subtype[2] == 'IIn':
                II_n.append(filename)
            elif subtype[2] == 'IIb':
                II_b.append(filename)
            elif subtype[2] == 'II':
                II.append(filename)
print(len(II_P))
print(len(II_n))
print(len(II_b))
print(len(II))
print(II)
# Out:
# 2019lbi.snana.dat SPEC_CLASS: SN II
#
# 2019ppi.snana.dat SPEC_CLASS: SN II
#
# 2019uez.snana.dat SPEC_CLASS: SN II
#
# 2019uit.snana.dat SPEC_CLASS: SN IIn
#
# 2019wmr.snana.dat SPEC_CLASS: SN II
#
# 2020aafm.snana.dat SPEC_CLASS: SN II
#
# 2020abjq.snana.dat SPEC_CLASS: SN II
#
# 2020absk.snana.dat SPEC_CLASS: SN II
#
# 2020acct.snana.dat SPEC_CLASS: SN IIn
#
# 2020acun.snana.dat SPEC_CLASS: SN II
#
# 2020aczd.snana.dat SPEC_CLASS: SN II
#
# 2020aeeg.snana.dat SPEC_CLASS: SN II
#
# 2020aeqx.snana.dat SPEC_CLASS: SN IIP
#
# 2020ama.snana.dat SPEC_CLASS: SN II
#
# 2020awg.snana.dat SPEC_CLASS: SN II
#
# 2020azh.snana.dat SPEC_CLASS: SN II
#
# 2020bwr.snana.dat SPEC_CLASS: SN II
#
# 2020dbd.snana.dat SPEC_CLASS: SN II
#
# 2020eaf.snana.dat SPEC_CLASS: SN II
#
# 2020ej.snana.dat SPEC_CLASS: SN II
#
# 2020fc.snana.dat SPEC_CLASS: SN II
#
# 2020fqv.snana.dat SPEC_CLASS: SN IIb
#
# 2020gcv.snana.dat SPEC_CLASS: SN II
#
# 2020ghq.snana.dat SPEC_CLASS: SN II
#
# 2020hgw.snana.dat SPEC_CLASS: SN II
#
# 2020hrw.snana.dat SPEC_CLASS: SN II
#
# 2020ikq.snana.dat SPEC_CLASS: SN IIb
#
# 2020ivg.snana.dat SPEC_CLASS: SN IIb
#
# 2020jfo.snana.dat SPEC_CLASS: SN II
#
# 2020jhs.snana.dat SPEC_CLASS: SN IIn
#
# 2020jww.snana.dat SPEC_CLASS: SN II
#
# 2020koc.snana.dat SPEC_CLASS: SN II
#
# 2020kpz.snana.dat SPEC_CLASS: SN II
#
# 2020lfi.snana.dat SPEC_CLASS: SN II
#
# 2020lrr.snana.dat SPEC_CLASS: SN II
#
# 2020mks.snana.dat SPEC_CLASS: SN II
#
# 2020nap.snana.dat SPEC_CLASS: SN II
#
# 2020nim.snana.dat SPEC_CLASS: SN II
#
# 2020noz.snana.dat SPEC_CLASS: SN IIn
#
# 2020ofw.snana.dat SPEC_CLASS: SN II
#
# 2020ovk.snana.dat SPEC_CLASS: SN II
#
# 2020pni.snana.dat SPEC_CLASS: SN II
#
# 2020qmj.snana.dat SPEC_CLASS: SN IIn
#
# 2020qmo.snana.dat SPEC_CLASS: SN II
#
# 2020rhg.snana.dat SPEC_CLASS: SN II
#
# 2020rth.snana.dat SPEC_CLASS: SN II
#
# 2020shf.snana.dat SPEC_CLASS: SN II
#
# 2020svn.snana.dat SPEC_CLASS: SN II
#
# 2020tan.snana.dat SPEC_CLASS: SN IIn
#
# 2020tfb.snana.dat SPEC_CLASS: SN IIP
#
# 2020thx.snana.dat SPEC_CLASS: SN II
#
# 2020tjd.snana.dat SPEC_CLASS: SN IIb
#
# 2020tkc.snana.dat SPEC_CLASS: SN IIb
#
# 2020tlf.snana.dat SPEC_CLASS: SN IIn
#
# 2020tly.snana.dat SPEC_CLASS: SN II
#
# 2020tzs.snana.dat SPEC_CLASS: SN II
#
# 2020uaq.snana.dat SPEC_CLASS: SN IIn
#
# 2020uhm.snana.dat SPEC_CLASS: SN II
#
# 2020utm.snana.dat SPEC_CLASS: SN IIn
#
# 2020uwl.snana.dat SPEC_CLASS: SN II
#
# 2020vdk.snana.dat SPEC_CLASS: SN II
#
# 2020whv.snana.dat SPEC_CLASS: SN II
#
# 2020xua.snana.dat SPEC_CLASS: SN II
#
# 2020ybn.snana.dat SPEC_CLASS: SN IIn
#
# 2020ykb.snana.dat SPEC_CLASS: SN II
#
# 2020ytg.snana.dat SPEC_CLASS: SN II
#
# 2020zx.snana.dat SPEC_CLASS: SN II
#
# 2021aaej.snana.dat SPEC_CLASS: SN II
#
# 2021aapa.snana.dat SPEC_CLASS: SN IIn
#
# 2021aaqn.snana.dat SPEC_CLASS: SN II
#
# 2021aceh.snana.dat SPEC_CLASS: SN II
#
# 2021acey.snana.dat SPEC_CLASS: SN II
#
# 2021acfc.snana.dat SPEC_CLASS: SN II
#
# 2021achy.snana.dat SPEC_CLASS: SN II
#
# 2021aff.snana.dat SPEC_CLASS: SN II
#
# 2021alq.snana.dat SPEC_CLASS: SN II
#
# 2021arg.snana.dat SPEC_CLASS: SN II
#
# 2021bmv.snana.dat SPEC_CLASS: SN IIn
#
# 2021btn.snana.dat SPEC_CLASS: SN II
#
# 2021bug.snana.dat SPEC_CLASS: SN II
#
# 2021bwv.snana.dat SPEC_CLASS: SN II
#
# 2021dbg.snana.dat SPEC_CLASS: SN II
#
# 2021fsb.snana.dat SPEC_CLASS: SN IIb
#
# 2021gdz.snana.dat SPEC_CLASS: SN II
#
# 2021hud.snana.dat SPEC_CLASS: SN II
#
# 2021hxv.snana.dat SPEC_CLASS: SN II
#
# 2021ihp.snana.dat SPEC_CLASS: SN II
#
# 2021inc.snana.dat SPEC_CLASS: SN II
#
# 2021jvl.snana.dat SPEC_CLASS: SN II
#
# 2021kcz.snana.dat SPEC_CLASS: SN II
#
# 2021krc.snana.dat SPEC_CLASS: SN II
#
# 2021nip.snana.dat SPEC_CLASS: SN II
#
# 2021nue.snana.dat SPEC_CLASS: SN II
#
# 2021pj.snana.dat SPEC_CLASS: SN II
#
# 2021pnp.snana.dat SPEC_CLASS: SN IIb
#
# 2021qes.snana.dat SPEC_CLASS: SN II
#
# 2021qvr.snana.dat SPEC_CLASS: SN II
#
# 2021qzi.snana.dat SPEC_CLASS: SN II
#
# 2021rem.snana.dat SPEC_CLASS: SN II
#
# 2021sev.snana.dat SPEC_CLASS: SN II
#
# 2021skm.snana.dat SPEC_CLASS: SN II
#
# 2021udc.snana.dat SPEC_CLASS: SN IIb
#
# 2021ukf.snana.dat SPEC_CLASS: SN II
#
# 2021uqw.snana.dat SPEC_CLASS: SN IIb
#
# 2021vgn.snana.dat SPEC_CLASS: SN II
#
# 2021vrt.snana.dat SPEC_CLASS: SN II
#
# 2021whv.snana.dat SPEC_CLASS: SN II
#
# 2021wjs.snana.dat SPEC_CLASS: SN II
#
# 2021wlr.snana.dat SPEC_CLASS: SN II
#
# 2021wvw.snana.dat SPEC_CLASS: SN II
#
# 2021xbf.snana.dat SPEC_CLASS: SN II
#
# 2021xre.snana.dat SPEC_CLASS: SN IIn
#
# 2021ybc.snana.dat SPEC_CLASS: SN IIb
#
# 2021zzv.snana.dat SPEC_CLASS: SN II
#
# 2
# 13
# 10
# 89
# ['2019lbi.snana.dat', '2019ppi.snana.dat', '2019uez.snana.dat', '2019wmr.snana.dat', '2020aafm.snana.dat', '2020abjq.snana.dat', '2020absk.snana.dat', '2020acun.snana.dat', '2020aczd.snana.dat', '2020aeeg.snana.dat', '2020ama.snana.dat', '2020awg.snana.dat', '2020azh.snana.dat', '2020bwr.snana.dat', '2020dbd.snana.dat', '2020eaf.snana.dat', '2020ej.snana.dat', '2020fc.snana.dat', '2020gcv.snana.dat', '2020ghq.snana.dat', '2020hgw.snana.dat', '2020hrw.snana.dat', '2020jfo.snana.dat', '2020jww.snana.dat', '2020koc.snana.dat', '2020kpz.snana.dat', '2020lfi.snana.dat', '2020lrr.snana.dat', '2020mks.snana.dat', '2020nap.snana.dat', '2020nim.snana.dat', '2020ofw.snana.dat', '2020ovk.snana.dat', '2020pni.snana.dat', '2020qmo.snana.dat', '2020rhg.snana.dat', '2020rth.snana.dat', '2020shf.snana.dat', '2020svn.snana.dat', '2020thx.snana.dat', '2020tly.snana.dat', '2020tzs.snana.dat', '2020uhm.snana.dat', '2020uwl.snana.dat', '2020vdk.snana.dat', '2020whv.snana.dat', '2020xua.snana.dat', '2020ykb.snana.dat', '2020ytg.snana.dat', '2020zx.snana.dat', '2021aaej.snana.dat', '2021aaqn.snana.dat', '2021aceh.snana.dat', '2021acey.snana.dat', '2021acfc.snana.dat', '2021achy.snana.dat', '2021aff.snana.dat', '2021alq.snana.dat', '2021arg.snana.dat', '2021btn.snana.dat', '2021bug.snana.dat', '2021bwv.snana.dat', '2021dbg.snana.dat', '2021gdz.snana.dat', '2021hud.snana.dat', '2021hxv.snana.dat', '2021ihp.snana.dat', '2021inc.snana.dat', '2021jvl.snana.dat', '2021kcz.snana.dat', '2021krc.snana.dat', '2021nip.snana.dat', '2021nue.snana.dat', '2021pj.snana.dat', '2021qes.snana.dat', '2021qvr.snana.dat', '2021qzi.snana.dat', '2021rem.snana.dat', '2021sev.snana.dat', '2021skm.snana.dat', '2021ukf.snana.dat', '2021vgn.snana.dat', '2021vrt.snana.dat', '2021whv.snana.dat', '2021wjs.snana.dat', '2021wlr.snana.dat', '2021wvw.snana.dat', '2021xbf.snana.dat', '2021zzv.snana.dat']
